# %%
import skimage.io as io
import matplotlib.pyplot as plt

# Read the image
img = io.imread('data/punto10_spectrum.png')
img.shape
# Out:
# (498, 556, 4)

# %%
# recorte hasta 80
img = img[:, 1:493, :]
img.shape
# Out:
# (498, 492, 4)

# %%
# 492 es a 80 como x es a 10
x1 = 9.7 * 492 / 80 # linea en 10
x1

x2 = 11.5 * 492 / 80 # linea en 11

# %%
plt.imshow(img)
plt.axvline(x1, color='r')
plt.axvline(x2, color='r')
#plt.axvline(2*x1, color='r')
#plt.axvline(6*x1, color='r')
plt.axis('off')
# Out:
# (-0.5, 491.5, 497.5, -0.5)
